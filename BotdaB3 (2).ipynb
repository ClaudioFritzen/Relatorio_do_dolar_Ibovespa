# %%
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\bruna cirigaita\anaconda3\lib\site-packages (3.8.5)
# Requirement already satisfied: requests in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from webdriver-manager) (2.28.1)
# Requirement already satisfied: python-dotenv in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from webdriver-manager) (0.21.1)
# Requirement already satisfied: packaging in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from webdriver-manager) (21.3)
# Requirement already satisfied: tqdm in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from webdriver-manager) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from packaging->webdriver-manager) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from requests->webdriver-manager) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.11)
# Requirement already satisfied: colorama in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.5)

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\bruna cirigaita\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: trio~=0.17 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sniffio in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: idna in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: outcome in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\bruna cirigaita\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: webencodings in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from html5lib) (1.16.0)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\bruna cirigaita\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import time 
import pandas as pd

# %%
# usando o chat gpt
import time

from selenium import webdriver

from selenium.webdriver.chrome.service import Service

service = Service('/path/to/chromedriver')

service.start()

driver = webdriver.Remote(service.service_url)


driver.get('http://www.facebook.com/');

time.sleep(60) # Let the user actually see something!

driver.quit()

# %%
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))
 
    
#url = "https://www.b3.com.br/pt_br/"
url = "https://www.etf.com/etfanalytics/etf-finder"
driver.get(url)

# %% [markdown]
# # Conhecer e mapear o processo de coleta de dados no site da EFT
# https://www.etf.com/

# %% [markdown]
# Entraremos no site da etf
# Entraremos em databases
# Colocar em vizualição por pagina em 100

# %% [markdown]
# # 5.1 Achar todos os elementos necessários detro do HTML - Expandindo a tabela para 100 por pagina

# %%
time.sleep(12)

botao100 = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[1]/div/div[4]/button/label/span''')

driver.execute_script("arguments[0].click();", botao100)

# %% [markdown]
# # 5.2 Achar todos os elementos necessários dentro do HTML - Pegando o números de paginas na tabela

# %%
numeros_de_pag = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/label[2]''')

# apos pegar o numeros de pagina deixamos apenas 
numeros_de_pag = numeros_de_pag.text.replace("of ","")
numeros_de_pag = int(numeros_de_pag)

print(numeros_de_pag)
# Out:
# 32

# %% [markdown]
# # 6.1 Lendo a tabela de dados

# %%
# aprender a tabela 1

tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/div/table''')

html = tabela.get_attribute("outerHTML")

# lendo html com pandas 
tabela_final = pd.read_html(html)[0]

display(tabela_final)
# Out:
#    Ticker                                         Name  \
# 0     SPY                       SPDR S&P 500 ETF Trust
# 1     IVV                     iShares Core S&P 500 ETF
# 2     VTI              Vanguard Total Stock Market ETF
# 3     VOO                         Vanguard S&P 500 ETF
# 4     QQQ                            Invesco QQQ Trust
# ..    ...                                          ...
# 95    XLI           Industrial Select Sector SPDR Fund
# 96    PFF  iShares Preferred and Income Securities ETF
# 97   USFR       WisdomTree Floating Rate Treasury Fund
# 98   SCHP                         Schwab U.S. TIPS ETF
# 99    BIV          Vanguard Intermediate-Term Bond ETF
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                         Equity: U.S. - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 95                           Equity: U.S. Industrials
# 96          Fixed Income: U.S. - Corporate, Preferred
# 97  Fixed Income: U.S. - Government, Treasury Inve...
# 98  Fixed Income: U.S. - Government, Inflation-lin...
# 99  Fixed Income: U.S. - Broad Market, Broad-based...
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $363.23B
# 1                      Blackrock         0.03%  $299.09B
# 2                       Vanguard         0.03%  $276.75B
# 3                       Vanguard         0.03%  $275.25B
# 4                        Invesco         0.20%  $157.36B
# ..                           ...           ...       ...
# 95  State Street Global Advisors         0.10%   $13.83B
# 96                     Blackrock         0.45%   $13.63B
# 97                    WisdomTree         0.15%   $13.57B
# 98                Charles Schwab         0.04%   $13.51B
# 99                      Vanguard         0.04%   $13.42B
#
# [100 rows x 6 columns]

# %%
# abrindo todas as paginas


# criando uma variavel para salvar a lista de paginas
# recebe uma lista vazia 
lista_de_paginas = []

# percorrendo todas as paginas
for pages in range(0, numeros_de_pag):
    
    tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/div/table''')

    html = tabela.get_attribute("outerHTML")

    # lendo html com pandas 
    tabela_final = pd.read_html(html)[0]
    
    # append para add um item na tabela
    lista_de_paginas.append(tabela_final)
    
    # botao avançar pagina
    botao_proxima_pagina = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]''')
    
    driver.execute_script("arguments[0].click();",botao_proxima_pagina)
    
base_de_dados_completa = pd.concat(lista_de_paginas)

display(base_de_dados_completa)
# Out:
#    Ticker                                               Name  \
# 0     SPY                             SPDR S&P 500 ETF Trust
# 1     IVV                           iShares Core S&P 500 ETF
# 2     VTI                    Vanguard Total Stock Market ETF
# 3     VOO                               Vanguard S&P 500 ETF
# 4     QQQ                                  Invesco QQQ Trust
# ..    ...                                                ...
# 5    CVIE        Calvert International Responsible Index ETF
# 6    CDEI  Calvert US Large-Cap Diversity, Equity and Inc...
# 7    CVSE                       Calvert US Select Equity ETF
# 8    SROI  Calamos Antetokounmpo Global Sustainable Equit...
# 9    CVSB           Calvert Ultra-Short Investment Grade ETF
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                         Equity: U.S. - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 5       Equity: Developed Markets Ex-U.S. - Large Cap
# 6                            Equity: U.S. - Large Cap
# 7                            Equity: U.S. - Large Cap
# 8                       Equity: Global - Total Market
# 9   Fixed Income: Global - Broad Market, Broad-bas...
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $363.23B
# 1                      Blackrock         0.03%  $299.09B
# 2                       Vanguard         0.03%  $276.75B
# 3                       Vanguard         0.03%  $275.25B
# 4                        Invesco         0.20%  $157.36B
# ..                           ...           ...       ...
# 5                 Morgan Stanley         0.18%        --
# 6                 Morgan Stanley         0.14%        --
# 7                 Morgan Stanley         0.29%        --
# 8        Calamos Family Partners            --        --
# 9                 Morgan Stanley         0.24%        --
#
# [3110 rows x 6 columns]

# %% [markdown]
# # Passo 6.2 Ler a tabela de dados -- Lendo a tabela de dados de rentabilidade

# %%
rentabilidade = driver.find_element('xpath', '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/ul/li[2]/span''')

#clicando no aba de rentabilidade
driver.execute_script('arguments[0].click();', rentabilidade)

# %%
# agora temos que voltar todas as paginas

# sera que da pra fazer  o reverso do outro
# tipo ja to na 32 entao fazer descer ate a numero um
# bota tentar

#pegar o xpath do botão de voltar


lista_de_paginas = []

for voltar in range(0, numeros_de_pag):
    botao_voltar = driver.find_element("xpath", '''//*[@id="previousPage"]''')
    driver.execute_script('arguments[0].click();', botao_voltar)

# aqui se repete o codigo anterior
    
# percorrendo todas as paginas
for pages in range(0, numeros_de_pag):
    
    tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/div/table''')

    html = tabela.get_attribute("outerHTML")

    # lendo html com pandas 
    tabela_final = pd.read_html(html)[0]
    
    # append para add um item na tabela
    lista_de_paginas.append(tabela_final)
    
    # botao avançar pagina
    botao_proxima_pagina = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]''')
    
    driver.execute_script("arguments[0].click();",botao_proxima_pagina)
    
base_de_dados_performace = pd.concat(lista_de_paginas)

display(base_de_dados_performace)
# Out:
#    Ticker                                               Name 1 Month 3 Month  \
# 0     SPY                             SPDR S&P 500 ETF Trust   0.01%   0.03%
# 1     IVV                           iShares Core S&P 500 ETF   0.01%   0.02%
# 2     VTI                    Vanguard Total Stock Market ETF   0.22%   0.66%
# 3     VOO                               Vanguard S&P 500 ETF   0.01%   0.02%
# 4     QQQ                                  Invesco QQQ Trust   2.72%   3.02%
# ..    ...                                                ...     ...     ...
# 5    CVIE        Calvert International Responsible Index ETF      --      --
# 6    CDEI  Calvert US Large-Cap Diversity, Equity and Inc...      --      --
# 7    CVSE                       Calvert US Select Equity ETF      --      --
# 8    SROI  Calamos Antetokounmpo Global Sustainable Equit...      --      --
# 9    CVSB           Calvert Ultra-Short Investment Grade ETF      --      --
#
#        YTD  1 Year 3 Years 5 Years 10 Years As Of Date
# 0    4.77%  -3.50%   8.01%   9.71%   12.26%   02/23/23
# 1    4.75%  -3.44%   8.01%   9.75%   12.31%   02/23/23
# 2    5.51%  -3.67%   7.53%   9.29%   11.93%   02/23/23
# 3    4.79%  -3.49%   8.00%   9.74%   12.32%   02/23/23
# 4   11.47%  -9.23%   9.50%  12.84%   17.11%   02/23/23
# ..     ...     ...     ...     ...      ...        ...
# 5       --      --      --      --       --   02/23/23
# 6       --      --      --      --       --   02/23/23
# 7       --      --      --      --       --   02/23/23
# 8       --      --      --      --       --   02/23/23
# 9       --      --      --      --       --   02/23/23
#
# [3110 rows x 10 columns]

# %%
# fechando o navegador
driver.quit()

# %%
display(base_de_dados_completa)
# Out:
#    Ticker                                               Name  \
# 0     SPY                             SPDR S&P 500 ETF Trust
# 1     IVV                           iShares Core S&P 500 ETF
# 2     VTI                    Vanguard Total Stock Market ETF
# 3     VOO                               Vanguard S&P 500 ETF
# 4     QQQ                                  Invesco QQQ Trust
# ..    ...                                                ...
# 5    CVIE        Calvert International Responsible Index ETF
# 6    CDEI  Calvert US Large-Cap Diversity, Equity and Inc...
# 7    CVSE                       Calvert US Select Equity ETF
# 8    SROI  Calamos Antetokounmpo Global Sustainable Equit...
# 9    CVSB           Calvert Ultra-Short Investment Grade ETF
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                         Equity: U.S. - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 5       Equity: Developed Markets Ex-U.S. - Large Cap
# 6                            Equity: U.S. - Large Cap
# 7                            Equity: U.S. - Large Cap
# 8                       Equity: Global - Total Market
# 9   Fixed Income: Global - Broad Market, Broad-bas...
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $363.23B
# 1                      Blackrock         0.03%  $299.09B
# 2                       Vanguard         0.03%  $276.75B
# 3                       Vanguard         0.03%  $275.25B
# 4                        Invesco         0.20%  $157.36B
# ..                           ...           ...       ...
# 5                 Morgan Stanley         0.18%        --
# 6                 Morgan Stanley         0.14%        --
# 7                 Morgan Stanley         0.29%        --
# 8        Calamos Family Partners            --        --
# 9                 Morgan Stanley         0.24%        --
#
# [3110 rows x 6 columns]

# %% [markdown]
# # Juntando as duas tabelas em uma só

# %%
base_de_dados_performace = base_de_dados_performace.set_index('Ticker')
base_de_dados_performace = base_de_dados_performace[['3 Month','1 Year', '5 Years']]
base_de_dados_performace
# Out:
#        3 Month  1 Year 5 Years
# Ticker
# SPY      0.03%  -3.50%   9.71%
# IVV      0.02%  -3.44%   9.75%
# VTI      0.66%  -3.67%   9.29%
# VOO      0.02%  -3.49%   9.74%
# QQQ      3.02%  -9.23%  12.84%
# ...        ...     ...     ...
# CVIE        --      --      --
# CDEI        --      --      --
# CVSE        --      --      --
# SROI        --      --      --
# CVSB        --      --      --
#
# [3110 rows x 3 columns]

# %%
base_de_dados_final = base_de_dados_completa.join(base_de_dados_performace)
display(base_de_dados_final)
# Out:
#    Ticker                                       Name  \
# 0     SPY                     SPDR S&P 500 ETF Trust
# 0     VBK              Vanguard Small-Cap Growth ETF
# 0     XLB          Materials Select Sector SPDR Fund
# 0    VOOV                 Vanguard S&P 500 Value ETF
# 0    IBTE  iShares iBonds Dec 2024 Term Treasury ETF
# ..    ...                                        ...
# 99   VNMC         Natixis Vaughan Nelson Mid Cap ETF
# 99   CLNR                   IQ Cleaner Transport ETF
# 99   RATE           Global X Interest Rate Hedge ETF
# 99   TAAG               Trend Aggregation Growth ETF
# 99   TADS              The Active Dividend Stock ETF
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 0                     Equity: U.S. - Small Cap Growth
# 0                              Equity: U.S. Materials
# 0                      Equity: U.S. - Large Cap Value
# 0   Fixed Income: U.S. - Government, Treasury Inve...
# ..                                                ...
# 99                             Equity: U.S. - Mid Cap
# 99                            Equity: Global Mobility
# 99                     Alternatives:Spreads Inflation
# 99                 Equity: U.S. - Total Market Growth
# 99                        Equity: U.S. - Total Market
#
#                                       Issuer Expense Ratio       AUM 3 Month  \
# 0               State Street Global Advisors         0.09%  $363.23B     NaN
# 0                                   Vanguard         0.07%   $13.34B     NaN
# 0               State Street Global Advisors         0.10%    $5.88B     NaN
# 0                                   Vanguard         0.10%    $3.19B     NaN
# 0                                  Blackrock         0.07%    $1.92B     NaN
# ..                                       ...           ...       ...     ...
# 99                                   Natixis         0.85%    $7.39M     NaN
# 99                             New York Life         0.45%    $5.06M     NaN
# 99  Mirae Asset Global Investments Co., Ltd.         0.45%    $3.42M     NaN
# 99           Tuttle Tactical Management, LLC         1.69%    $1.97M     NaN
# 99           Tuttle Tactical Management, LLC         1.68%  $294.89K     NaN
#
#    1 Year 5 Years
# 0     NaN     NaN
# 0     NaN     NaN
# 0     NaN     NaN
# 0     NaN     NaN
# 0     NaN     NaN
# ..    ...     ...
# 99    NaN     NaN
# 99    NaN     NaN
# 99    NaN     NaN
# 99    NaN     NaN
# 99    NaN     NaN
#
# [3110 rows x 9 columns]

# %%
# !pip install webdriver-manager 
# !pip install selenium
# !pip install html5lib 
# !pip install pandas

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd

driver = webdriver.Chrome(service = Service(ChromeDriverManager().install())) 
#url = "https://www.b3.com.br/pt_br/"
url = "https://www.etf.com/etfanalytics/etf-finder"
driver.get(url)

time.sleep(12)
botao100 = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[1]/div/div[4]/button/label/span''')
driver.execute_script("arguments[0].click();", botao100)


time.sleep(12)
# pegando 
numeros_de_pag = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/label[2]''')

# apos pegar o numeros de pagina deixamos apenas 
numeros_de_pag = numeros_de_pag.text.replace("of ","")
numeros_de_pag = int(numeros_de_pag)

print(numeros_de_pag)

#
# abrindo todas as paginas


# criando uma variavel para salvar a lista de paginas
# recebe uma lista vazia 
lista_de_paginas = []

# percorrendo todas as paginas
for pages in range(0, numeros_de_pag):
    
    tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/div/table''')

    html = tabela.get_attribute("outerHTML")

    # lendo html com pandas 
    tabela_final = pd.read_html(html)[0]
    
    # append para add um item na tabela
    lista_de_paginas.append(tabela_final)
    
    # botao avançar pagina
    botao_proxima_pagina = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]''')
    
    driver.execute_script("arguments[0].click();",botao_proxima_pagina)
    
base_de_dados_completa = pd.concat(lista_de_paginas)

display(base_de_dados_completa)


## 
rentabilidade = driver.find_element('xpath', '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/ul/li[2]/span''')

#clicando no aba de rentabilidade
driver.execute_script('arguments[0].click();', rentabilidade)

##
# agora temos que voltar todas as paginas

# sera que da pra fazer  o reverso do outro
# tipo ja to na 32 entao fazer descer ate a numero um
# bota tentar

#pegar o xpath do botão de voltar


lista_de_paginas = []

for voltar in range(0, numeros_de_pag):
    botao_voltar = driver.find_element("xpath", '''//*[@id="previousPage"]''')
    driver.execute_script('arguments[0].click();', botao_voltar)

# aqui se repete o codigo anterior
    
# percorrendo todas as paginas
for pages in range(0, numeros_de_pag):
    
    tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/div/table''')

    html = tabela.get_attribute("outerHTML")

    # lendo html com pandas 
    tabela_final = pd.read_html(html)[0]
    
    # append para add um item na tabela
    lista_de_paginas.append(tabela_final)
    
    # botao avançar pagina
    botao_proxima_pagina = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]''')
    
    driver.execute_script("arguments[0].click();",botao_proxima_pagina)
    
base_de_dados_performace = pd.concat(lista_de_paginas)

display(base_de_dados_performace)

##
# fechando o navegador
driver.quit()

## 
display(base_de_dados_completa)


#########
base_de_dados_performace = base_de_dados_performace.set_index('Ticker')
base_de_dados_performace = base_de_dados_performace[['3 Month','1 Year', '5 Years']]
base_de_dados_performace

##
base_de_dados_final = base_de_dados_completa.join(base_de_dados_performace)
display(base_de_dados_final)
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\bruna cirigaita\anaconda3\lib\site-packages (3.8.5)
# Requirement already satisfied: requests in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from webdriver-manager) (2.28.1)
# Requirement already satisfied: tqdm in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from webdriver-manager) (4.64.1)
# Requirement already satisfied: python-dotenv in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from webdriver-manager) (0.21.1)
# Requirement already satisfied: packaging in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from webdriver-manager) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from packaging->webdriver-manager) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from requests->webdriver-manager) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.11)
# Requirement already satisfied: colorama in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.5)
# Requirement already satisfied: selenium in c:\users\bruna cirigaita\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio~=0.17 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: idna in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: async-generator>=1.9 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sniffio in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: sortedcontainers in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: html5lib in c:\users\bruna cirigaita\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: pandas in c:\users\bruna cirigaita\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\bruna cirigaita\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.78M/6.78M [00:01<00:00, 3.99MB/s]
# 32
#    Ticker                                               Name  \
# 0     SPY                             SPDR S&P 500 ETF Trust
# 1     IVV                           iShares Core S&P 500 ETF
# 2     VTI                    Vanguard Total Stock Market ETF
# 3     VOO                               Vanguard S&P 500 ETF
# 4     QQQ                                  Invesco QQQ Trust
# ..    ...                                                ...
# 5    CVIE        Calvert International Responsible Index ETF
# 6    CDEI  Calvert US Large-Cap Diversity, Equity and Inc...
# 7    CVSE                       Calvert US Select Equity ETF
# 8    SROI  Calamos Antetokounmpo Global Sustainable Equit...
# 9    CVSB           Calvert Ultra-Short Investment Grade ETF
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                         Equity: U.S. - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 5       Equity: Developed Markets Ex-U.S. - Large Cap
# 6                            Equity: U.S. - Large Cap
# 7                            Equity: U.S. - Large Cap
# 8                       Equity: Global - Total Market
# 9   Fixed Income: Global - Broad Market, Broad-bas...
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $363.23B
# 1                      Blackrock         0.03%  $299.09B
# 2                       Vanguard         0.03%  $276.75B
# 3                       Vanguard         0.03%  $275.25B
# 4                        Invesco         0.20%  $157.36B
# ..                           ...           ...       ...
# 5                 Morgan Stanley         0.18%        --
# 6                 Morgan Stanley         0.14%        --
# 7                 Morgan Stanley         0.29%        --
# 8        Calamos Family Partners            --        --
# 9                 Morgan Stanley         0.24%        --
#
# [3110 rows x 6 columns]
#    Ticker                                               Name 1 Month 3 Month  \
# 0     SPY                             SPDR S&P 500 ETF Trust   0.01%   0.03%
# 1     IVV                           iShares Core S&P 500 ETF   0.01%   0.02%
# 2     VTI                    Vanguard Total Stock Market ETF   0.22%   0.66%
# 3     VOO                               Vanguard S&P 500 ETF   0.01%   0.02%
# 4     QQQ                                  Invesco QQQ Trust   2.72%   3.02%
# ..    ...                                                ...     ...     ...
# 5    CVIE        Calvert International Responsible Index ETF      --      --
# 6    CDEI  Calvert US Large-Cap Diversity, Equity and Inc...      --      --
# 7    CVSE                       Calvert US Select Equity ETF      --      --
# 8    SROI  Calamos Antetokounmpo Global Sustainable Equit...      --      --
# 9    CVSB           Calvert Ultra-Short Investment Grade ETF      --      --
#
#        YTD  1 Year 3 Years 5 Years 10 Years As Of Date
# 0    4.77%  -3.50%   8.01%   9.71%   12.26%   02/23/23
# 1    4.75%  -3.44%   8.01%   9.75%   12.31%   02/23/23
# 2    5.51%  -3.67%   7.53%   9.29%   11.93%   02/23/23
# 3    4.79%  -3.49%   8.00%   9.74%   12.32%   02/23/23
# 4   11.47%  -9.23%   9.50%  12.84%   17.11%   02/23/23
# ..     ...     ...     ...     ...      ...        ...
# 5       --      --      --      --       --   02/23/23
# 6       --      --      --      --       --   02/23/23
# 7       --      --      --      --       --   02/23/23
# 8       --      --      --      --       --   02/23/23
# 9       --      --      --      --       --   02/23/23
#
# [3110 rows x 10 columns]
#    Ticker                                               Name  \
# 0     SPY                             SPDR S&P 500 ETF Trust
# 1     IVV                           iShares Core S&P 500 ETF
# 2     VTI                    Vanguard Total Stock Market ETF
# 3     VOO                               Vanguard S&P 500 ETF
# 4     QQQ                                  Invesco QQQ Trust
# ..    ...                                                ...
# 5    CVIE        Calvert International Responsible Index ETF
# 6    CDEI  Calvert US Large-Cap Diversity, Equity and Inc...
# 7    CVSE                       Calvert US Select Equity ETF
# 8    SROI  Calamos Antetokounmpo Global Sustainable Equit...
# 9    CVSB           Calvert Ultra-Short Investment Grade ETF
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                         Equity: U.S. - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 5       Equity: Developed Markets Ex-U.S. - Large Cap
# 6                            Equity: U.S. - Large Cap
# 7                            Equity: U.S. - Large Cap
# 8                       Equity: Global - Total Market
# 9   Fixed Income: Global - Broad Market, Broad-bas...
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $363.23B
# 1                      Blackrock         0.03%  $299.09B
# 2                       Vanguard         0.03%  $276.75B
# 3                       Vanguard         0.03%  $275.25B
# 4                        Invesco         0.20%  $157.36B
# ..                           ...           ...       ...
# 5                 Morgan Stanley         0.18%        --
# 6                 Morgan Stanley         0.14%        --
# 7                 Morgan Stanley         0.29%        --
# 8        Calamos Family Partners            --        --
# 9                 Morgan Stanley         0.24%        --
#
# [3110 rows x 6 columns]
#    Ticker                                       Name  \
# 0     SPY                     SPDR S&P 500 ETF Trust
# 0     VBK              Vanguard Small-Cap Growth ETF
# 0     XLB          Materials Select Sector SPDR Fund
# 0    VOOV                 Vanguard S&P 500 Value ETF
# 0    IBTE  iShares iBonds Dec 2024 Term Treasury ETF
# ..    ...                                        ...
# 99   VNMC         Natixis Vaughan Nelson Mid Cap ETF
# 99   CLNR                   IQ Cleaner Transport ETF
# 99   RATE           Global X Interest Rate Hedge ETF
# 99   TAAG               Trend Aggregation Growth ETF
# 99   TADS              The Active Dividend Stock ETF
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 0                     Equity: U.S. - Small Cap Growth
# 0                              Equity: U.S. Materials
# 0                      Equity: U.S. - Large Cap Value
# 0   Fixed Income: U.S. - Government, Treasury Inve...
# ..                                                ...
# 99                             Equity: U.S. - Mid Cap
# 99                            Equity: Global Mobility
# 99                     Alternatives:Spreads Inflation
# 99                 Equity: U.S. - Total Market Growth
# 99                        Equity: U.S. - Total Market
#
#                                       Issuer Expense Ratio       AUM 3 Month  \
# 0               State Street Global Advisors         0.09%  $363.23B     NaN
# 0                                   Vanguard         0.07%   $13.34B     NaN
# 0               State Street Global Advisors         0.10%    $5.88B     NaN
# 0                                   Vanguard         0.10%    $3.19B     NaN
# 0                                  Blackrock         0.07%    $1.92B     NaN
# ..                                       ...           ...       ...     ...
# 99                                   Natixis         0.85%    $7.39M     NaN
# 99                             New York Life         0.45%    $5.06M     NaN
# 99  Mirae Asset Global Investments Co., Ltd.         0.45%    $3.42M     NaN
# 99           Tuttle Tactical Management, LLC         1.69%    $1.97M     NaN
# 99           Tuttle Tactical Management, LLC         1.68%  $294.89K     NaN
#
#    1 Year 5 Years
# 0     NaN     NaN
# 0     NaN     NaN
# 0     NaN     NaN
# 0     NaN     NaN
# 0     NaN     NaN
# ..    ...     ...
# 99    NaN     NaN
# 99    NaN     NaN
# 99    NaN     NaN
# 99    NaN     NaN
# 99    NaN     NaN
#
# [3110 rows x 9 columns]
